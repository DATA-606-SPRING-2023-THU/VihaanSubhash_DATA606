# %% [markdown]
# # Sentimental Analysis On Online Reviews
#
# Online reviews are a rich source of text data that may be examined to learn what customers think and feel about a product or service. For businesses looking to better understand their clients and enhance their offerings and services, this information can be helpful.
#
# The goal of the sentiment analysis model of online reviews is to automatically recognize and categorize the sentiment indicated in a written text as positive, negative, or neutral. Understanding customers ideas, feedback, and experiences with a company's goods or services is made possible through the sentiment analysis of online reviews, which can be helpful for making adjustments, spotting trends, and making wise judgments.

# %% [markdown]
# ## Importing packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Importing Data

# %%
Online_Reviews = pd.read_csv('245_1.csv')

# %% [markdown]
# ## Data Exploration

# %%
Online_Reviews.head(5)
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
# ...

# %%
Online_Reviews.columns = Online_Reviews.columns.str.replace(".", "_")
# Out:
# C:\Users\mviha\AppData\Local\Temp\ipykernel_3920\3875832920.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Online_Reviews.columns = Online_Reviews.columns.str.replace(".", "_")

# %%
Online_Reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71044 entries, 0 to 71043
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    71044 non-null  object
#  1   brand                 71044 non-null  object
#  2   categories            71044 non-null  object
#  3   dateAdded             71044 non-null  object
#  4   dateUpdated           71044 non-null  object
#  5   ean                   39065 non-null  object
#  6   keys                  71044 non-null  object
#  7   manufacturer          70903 non-null  object
#  8   manufacturerNumber    70841 non-null  object
#  9   name                  71044 non-null  object
#  10  reviews_date          70977 non-null  object
#  11  reviews_dateAdded     71044 non-null  object
#  12  reviews_dateSeen      71044 non-null  object
#  13  reviews_didPurchase   32158 non-null  object
#  14  reviews_doRecommend   60429 non-null  object
# ...

# %%
Online_Reviews.head(5)
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
# ...

# %%
Online_Reviews.describe().round(2)
# Out:
#          reviews_id  reviews_numHelpful  reviews_rating
# count  3.215800e+04            32508.00        71044.00
# mean   7.944753e+07                0.41            4.39
# std    4.842696e+07                3.57            1.07
# min    2.187400e+04                0.00            1.00
# 25%    3.355342e+07                0.00            4.00
# 50%    7.124763e+07                0.00            5.00
# 75%    1.112628e+08                0.00            5.00
# max    1.038227e+09              183.00            5.00

# %% [markdown]
# ## Missing Values

# %%
Online_Reviews.isnull().any()
# Out:
# id                      False
# brand                   False
# categories              False
# dateAdded               False
# dateUpdated             False
# ean                      True
# keys                    False
# manufacturer             True
# manufacturerNumber       True
# name                    False
# reviews_date             True
# reviews_dateAdded       False
# reviews_dateSeen        False
# reviews_didPurchase      True
# reviews_doRecommend      True
# reviews_id               True
# reviews_numHelpful       True
# reviews_rating          False
# reviews_sourceURLs      False
# reviews_text             True
# reviews_title            True
# reviews_userCity         True
# reviews_userProvince     True
# reviews_username         True
# upc                      True
# dtype: bool

# %%
Online_Reviews.dropna(how='any', inplace=True)

# %%
Online_Reviews.isnull().any()
# Out:
# id                      False
# brand                   False
# categories              False
# dateAdded               False
# dateUpdated             False
# ean                     False
# keys                    False
# manufacturer            False
# manufacturerNumber      False
# name                    False
# reviews_date            False
# reviews_dateAdded       False
# reviews_dateSeen        False
# reviews_didPurchase     False
# reviews_doRecommend     False
# reviews_id              False
# reviews_numHelpful      False
# reviews_rating          False
# reviews_sourceURLs      False
# reviews_text            False
# reviews_title           False
# reviews_userCity        False
# reviews_userProvince    False
# reviews_username        False
# upc                     False
# dtype: bool

# %%
Online_Reviews.isnull().sum()
# Out:
# id                      0.0
# brand                   0.0
# categories              0.0
# dateAdded               0.0
# dateUpdated             0.0
# ean                     0.0
# keys                    0.0
# manufacturer            0.0
# manufacturerNumber      0.0
# name                    0.0
# reviews_date            0.0
# reviews_dateAdded       0.0
# reviews_dateSeen        0.0
# reviews_didPurchase     0.0
# reviews_doRecommend     0.0
# reviews_id              0.0
# reviews_numHelpful      0.0
# reviews_rating          0.0
# reviews_sourceURLs      0.0
# reviews_text            0.0
# reviews_title           0.0
# reviews_userCity        0.0
# reviews_userProvince    0.0
# reviews_username        0.0
# upc                     0.0
# dtype: float64

# %% [markdown]
# ## VISUALIZATION
